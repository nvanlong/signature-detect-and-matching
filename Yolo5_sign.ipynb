# %%
# !nvidia-smi
# Out:
# Sat Sep 11 14:03:40 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/MyDrive/SignatureDetection/yolov5'
# Out:
# /content/drive/MyDrive/SignatureDetection/yolov5

# %%
ls
# Out:
# Arial.ttf        Dockerfile  models/           runs/           val.py
# CONTRIBUTING.md  export.py   __pycache__/      train.py        wandb/
# data/            hubconf.py  README.md         tutorial.ipynb  yolo_sign/
# detect.py        LICENSE     requirements.txt  utils/          yolov5l.pt

# %%
# !pip install -r requirements.txt

# %%
# !pip install wandb -qqq

# %%
# Log in to your W&B account
import wandb
wandb.login()
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # 100 epoch

# %%
#!python train.py --data tobacco800.yaml --project yolo_sign --save_period 1 --batch 20 --epochs 100 --bbox_interval 1 --cfg ./models/custom_yolov5l.yaml --weights '' --name yolo5_tobacco --device cpu
# !python train.py --data tobacco800.yaml --project yolo_sign --batch 10 --epochs 100 --bbox_interval 1 --cfg ./models/custom_yolov5l.yaml --weights '' --name yolo5_tobacco
# Out:
# train: weights=, cfg=./models/custom_yolov5l.yaml, data=tobacco800.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=10, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolo_sign, entity=None, name=yolo5_tobacco, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=30
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2021-9-1 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# !python train.py --data tobacco800.yaml --project yolo_sign --batch 5 --epochs 100 --weights yolov5l.pt --name yolo5l_tobacco

# %%
# !python detect.py --source ../datasets/tobacco800/images/test/ --weights yolo_sign/yolo5_tobacco/weights/best.pt --classes 0 --name tobacco800
# Out:
# image 1246/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/yru03f00-page03_3.tif: 640x512 1 sign, Done. (0.102s)
# image 1247/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/yrz52d00.tif: 640x512 1 sign, Done. (0.102s)
# image 1248/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/yte65e00.tif: 640x512 Done. (0.101s)
# image 1249/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/ytz94a00.tif: 640x544 1 sign, Done. (0.105s)
# image 1250/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/yum00a00.tif: 640x512 2 signs, Done. (0.100s)
# image 1251/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/yyj15f00-page3_1.tif: 640x512 Done. (0.098s)
# ...

# %%
# !python val.py --weights yolo_sign/yolo5_tobacco/weights/best.pt --data tobacco800.yaml --img 640 --iou 0.65 --name tobacco
# Out:
# val: data=./data/tobacco800.yaml, weights=['yolo_sign/yolo5_tobacco/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=tobacco, exist_ok=False, half=False
# YOLOv5 🚀 2021-9-1 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46600566 parameters, 0 gradients, 114.1 GFLOPs
# val: Scanning '../datasets/tobacco800/labels/val.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupted: 100% 20/20 [00:00<?, ?it/s]
# val: Scanning '../datasets/tobacco800/labels/val.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupted: 100% 20/20 [00:01<?, ?it/s]
# val: Scanning '../datasets/tobacco800/labels/val.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupted: 100% 20/20 [00:01<?, ?it/s]
# ...

# %%
# !python export.py --weights yolo_sign/yolo5_tobacco/weights/best.pt

# %% [markdown]
# # 300 epoch

# %%
# !python train.py --data tobacco800.yaml --project yolo_sign --batch 10 --epochs 300 --bbox_interval 1 --cfg ./models/custom_yolov5l.yaml --weights '' --name yolo5l_300_tobacco
# Out:
# train: weights=, cfg=./models/custom_yolov5l.yaml, data=tobacco800.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=10, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolo_sign, entity=None, name=yolo5l_300_tobacco, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=30
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2021-9-1 torch 1.9.0+cu102 CUDA:0 (Tesla P4, 7611.9375MB)
#
# ...

# %%
# !python val.py --weights yolo_sign/yolo5l_300_tobacco/weights/best.pt --data tobacco800.yaml --name tobacco800_300
# Out:
# val: data=./data/tobacco800.yaml, weights=['yolo_sign/yolo5l_300_tobacco/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=tobacco800_300, exist_ok=False, half=False
# YOLOv5 🚀 2021-9-1 torch 1.9.0+cu102 CUDA:0 (Tesla P4, 7611.9375MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46600566 parameters, 0 gradients, 114.1 GFLOPs
# val: Scanning '../datasets/tobacco800/labels/val.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupted: 100% 20/20 [00:00<?, ?it/s]
# val: Scanning '../datasets/tobacco800/labels/val.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupted: 100% 20/20 [00:01<?, ?it/s]
# val: Scanning '../datasets/tobacco800/labels/val.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupted: 100% 20/20 [00:01<?, ?it/s]
#
# ...

# %%
# !python val.py --weights yolo_sign/yolo5l_300_tobacco/weights/best.pt --data tobacco800.yaml --task test --name test_tobacco

# %%
# !python detect.py --source ../datasets/tobacco800/images/test/ --weights yolo_sign/yolo5l_300_tobacco/weights/best.pt --classes 0 --name test_tobacco800 --save-crop
# Out:
# image 1282/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/zqs18e00-page01_1.tif: 640x512 1 sign, Done. (0.038s)
# image 1283/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/zqs18e00-page01_2.tif: 640x512 Done. (0.037s)
# image 1284/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/zrt45f00.tif: 640x512 1 sign, Done. (0.038s)
# image 1285/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/zrz94a00-page02_1.tif: 640x544 Done. (0.046s)
# image 1286/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/zrz94a00-page02_2.tif: 640x544 1 sign, Done. (0.046s)
# image 1287/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/zss86d00.tif: 640x512 1 sign, Done. (0.039s)
# ...

# %%
from utils.plots import plot_results 
plot_results('yolo_sign/yolo5l_300_tobacco/results.csv')

# %% [markdown]
# # 300 epochs author signature

# %%
#!python train.py --data author_tobacco800.yaml --project yolo_sign --batch 10 --epochs 300 --bbox_interval 1 --cfg ./models/author_yolov5l.yaml --weights '' --name author_300_tobacco
# !python train.py --data author_tobacco800.yaml --project yolo_sign --cfg ./models/author_yolov5l.yaml --weights '' --name author_300_tobacco
# Out:
# train: weights=, cfg=./models/author_yolov5l.yaml, data=author_tobacco800.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolo_sign, entity=None, name=author_300_tobacco, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=30
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2021-9-1 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# !python train.py --data author_tobacco800.yaml --project yolo_sign --cfg ./models/author_yolov5l.yaml --weights yolo_sign/author_300_tobacco/weights/last.pt --name author_300_tobacco
# Out:
# train: weights=yolo_sign/author_300_tobacco/weights/last.pt, cfg=./models/author_yolov5l.yaml, data=author_tobacco800.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolo_sign, entity=None, name=author_300_tobacco, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=30
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2021-9-1 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# !python train.py --data author_tobacco800.yaml --project yolo_sign --cfg ./models/author_yolov5l.yaml --weights yolo_sign/author_300_tobacco2/weights/last.pt --name author_300_tobacco
# Out:
# train: weights=yolo_sign/author_300_tobacco2/weights/last.pt, cfg=./models/author_yolov5l.yaml, data=author_tobacco800.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolo_sign, entity=None, name=author_300_tobacco, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=30
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2021-9-1 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# !python val.py --weights yolo_sign/author_300_tobacco3/weights/best.pt --data author_tobacco800.yaml --name author_tobacco800
# Out:
# val: data=./data/author_tobacco800.yaml, weights=['yolo_sign/author_300_tobacco3/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=author_tobacco800, exist_ok=False, half=False
# YOLOv5 🚀 2021-9-1 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 392 layers, 47295231 parameters, 0 gradients, 116.3 GFLOPs
# val: Scanning '../datasets/author_tobacco800/labels/train.cache' images and labels... 258 found, 0 missing, 0 empty, 0 corrupted: 100% 258/258 [00:00<?, ?it/s]
# val: Scanning '../datasets/author_tobacco800/labels/train.cache' images and labels... 258 found, 0 missing, 0 empty, 0 corrupted: 100% 258/258 [00:04<?, ?it/s]
# ...

# %%
from utils.plots import plot_results 
plot_results('yolo_sign/author_300_tobacco/results.csv')

# %%
# !python detect.py --weights yolo_sign/author_300_tobacco3/weights/best.pt --source data/images/ --name author_tobacco800 --save-crop

# %%
# !python detect.py --weights yolo_sign/author_300_tobacco3/weights/best.pt --source ../datasets/tobacco800/images/test/ --name author_tobacco800 --save-crop
# Out:
# detect: weights=['yolo_sign/author_300_tobacco3/weights/best.pt'], source=../datasets/tobacco800/images/test/, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=author_tobacco800, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 2021-9-1 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 392 layers, 47295231 parameters, 0 gradients, 116.3 GFLOPs
# image 1/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/aah97e00-page02_1.tif: 640x512 Done. (0.113s)
# image 2/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/aah97e00-page02_2.tif: 640x512 Done. (0.114s)
# ...

# %%
# !python detect.py --weights yolo_sign/author_300_tobacco2/weights/best.pt --source ../datasets/tobacco800/images/test/ --name author_tobacco8002 --save-crop
# Out:
# detect: weights=['yolo_sign/author_300_tobacco2/weights/best.pt'], source=../datasets/tobacco800/images/test/, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=author_tobacco8002, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 2021-9-1 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 392 layers, 47295231 parameters, 0 gradients, 116.3 GFLOPs
# image 1/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/aah97e00-page02_1.tif: 640x512 Done. (0.112s)
# image 2/1290 /content/drive/My Drive/SignatureDetection/yolov5/../datasets/tobacco800/images/test/aah97e00-page02_2.tif: 640x512 Done. (0.107s)
# ...
